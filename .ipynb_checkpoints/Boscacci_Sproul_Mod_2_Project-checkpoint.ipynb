# %% [markdown]
# # Automotive Deaths by County

# %% [markdown]
# ### Which factors influence the rate of automotive deaths in US counties?

# %% [markdown]
# This is our first attempt to develop a multiple linear regression model.

# %% [markdown]
# We were curious about how the number of **taco bells** in any given state influenced the number of **diabetes** cases in that state, but ultimately realized that the sample size (50) wasn't large enough to be able to perform confident regression analysis.

# %% [markdown]
# After banging our heads against some other data from New York State regarding tax-incentivized **solar panel installations**, we realized that the data we had was not indicative of more general solar panel adoption, so we moved on once again.

# %% [markdown]
# Another dependent variable we considered was **alcohol-related motor vehicle deaths**, but the data we had was just a percentage of the total number of motor vehicle related deaths, which was causing problems for our model.

# %% [markdown]
# So, here we are. Given some attributes of a county, can we predict the number of motor vehicle deaths that will happen in a year in that county?

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import statsmodels.formula.api as smf
from statsmodels.formula.api import ols
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import style
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import VarianceThreshold, SelectKBest, f_regression, mutual_info_regression
from sklearn import linear_model, datasets, metrics, preprocessing, pipeline
from sklearn.linear_model import LinearRegression, Lasso
from string import ascii_letters

style.use('ggplot')
sns.set(style="ticks")

pd.set_option('display.max_rows', 200)
pd.set_option('display.max_columns', 200)
sns.set(style="white")

# %% [markdown]
# Just bringing in some data we picked up from https://datausa.io/:

# %%
df1, df2 = pd.read_csv('data/drunkdrivin_01.csv'), pd.read_csv('data/drunkdrivin_02.csv')
df3, df4 = pd.read_csv('data/drunkdrivin_03.csv'), pd.read_csv('data/drunkdrivin_04.csv')
df5 = pd.read_csv('data/drunkdrivin_05.csv')

# %%
joiner = pd.merge(df1, df2, how='left', on='geo_name')
joiner = pd.merge(joiner, df3, how='left', on='geo_name')
joiner = pd.merge(joiner, df4, how='left', on='geo_name')
joiner = pd.merge(joiner, df5, how='left', on='geo_name')

# %%
joiner[:3] # Here's the kitchen sink of our data:
# Out:
#              geo_name geo_sumlevel_x      geo_id_x  \
# 0  Autauga County, AL         county  05000US01001
# 1  Baldwin County, AL         county  05000US01003
# 2  Barbour County, AL         county  05000US01005
#
#    alcoholimpaired_driving_deaths_2015  alcoholimpaired_driving_deaths_2016  \
# 0                                0.333                                0.318
# 1                                0.303                                0.394
# 2                                0.435                                0.391
#
#    alcoholimpaired_driving_deaths_2017  \
# 0                                0.327
# 1                                0.342
# 2                                0.385
#
#    income_below_poverty:pop_poverty_status_2013  \
# 0                                      0.121334
# 1                                      0.139407
# 2                                      0.266568
#
#    income_below_poverty:pop_poverty_status_2014  \
# 0                                      0.128052
# 1                                      0.137768
# 2                                      0.240842
#
#    income_below_poverty:pop_poverty_status_2015  \
# 0                                      0.128794
# 1                                      0.134117
# 2                                      0.267274
#
#    income_below_poverty:pop_poverty_status_2016  income_2013  income_2014  \
# 0                                      0.122660      53682.0      52475.0
# 1                                      0.129938      50221.0      50183.0
# 2                                      0.263737      32911.0      35634.0
#
#    income_2015  income_2016  income_below_poverty_2013  \
# 0      51281.0      53099.0                     6615.0
# 1      50254.0      51365.0                    25752.0
# 2      32964.0      33956.0                     6512.0
#
#    income_below_poverty_2014  income_below_poverty_2015  \
# 0                     7006.0                     7057.0
# 1                    25988.0                    25798.0
# 2                     5832.0                     6421.0
#
#    income_below_poverty_2016  pop_poverty_status_2013  \
# 0                     6697.0                  54519.0
# 1                    25551.0                 184725.0
# 2                     6235.0                  24429.0
#
#    pop_poverty_status_2014  pop_poverty_status_2015  pop_poverty_status_2016  \
# 0                  54712.0                  54793.0                  54598.0
# 1                 188636.0                 192355.0                 196640.0
# 2                  24215.0                  24024.0                  23641.0
#
#    unemployment_2015  unemployment_2016  unemployment_2017  uninsured_2015  \
# 0              0.057              0.059              0.052           0.128
# 1              0.058              0.061              0.055           0.158
# 2              0.100              0.108              0.089           0.175
#
#    uninsured_2016  uninsured_2017 geo_sumlevel_y      geo_id_y  \
# 0           0.134           0.110         county  05000US01001
# 1           0.175           0.161         county  05000US01003
# 2           0.174           0.153         county  05000US01005
#
#    high_school_graduation_2015  high_school_graduation_2016  \
# 0                        0.810                        0.830
# 1                        0.740                        0.800
# 2                        0.697                        0.805
#
#    high_school_graduation_2017  mean_commute_minutes_2013  \
# 0                        0.900                    25.6470
# 1                        0.850                    25.0430
# 2                        0.862                    24.0734
#
#    mean_commute_minutes_2014  mean_commute_minutes_2015  \
# 0                    26.3211                    26.0002
# 1                    25.5477                    25.3936
# 2                    23.9553                    23.6957
#
#    mean_commute_minutes_2016  motor_vehicle_crash_deaths_2015  \
# 0                    25.5584                            21.25
# 1                    25.8497                            16.57
# 2                    23.4419                            18.67
#
#    motor_vehicle_crash_deaths_2016  motor_vehicle_crash_deaths_2017  \
# 0                            19.72                            18.94
# 1                            15.90                            15.32
# 2                            18.22                            18.96
#
#    population_living_in_a_rural_area_2015  \
# 0                                   0.420
# 1                                   0.423
# 2                                   0.678
#
#    population_living_in_a_rural_area_2016  \
# 0                                   0.420
# 1                                   0.423
# 2                                   0.678
#
#    population_living_in_a_rural_area_2017  severe_housing_problems_2015  \
# 0                                   0.420                         0.123
# 1                                   0.423                         0.141
# 2                                   0.678                         0.186
#
#    severe_housing_problems_2016  severe_housing_problems_2017 geo_sumlevel_x  \
# 0                         0.136                         0.147         county
# 1                         0.147                         0.147         county
# 2                         0.176                         0.162         county
#
#        geo_id_x  adult_obesity_2015  adult_obesity_2016  adult_obesity_2017  \
# 0  05000US01001               0.313               0.309               0.341
# 1  05000US01003               0.250               0.267               0.274
# 2  05000US01005               0.384               0.408               0.444
#
#    medicare_beneficiaries_total_2010  medicare_beneficiaries_total_2011  \
# 0                                NaN                                NaN
# 1                            20820.0                            21017.0
# 2                             3166.0                             2920.0
#
#    medicare_beneficiaries_total_2012  medicare_beneficiaries_total_2013  \
# 0                                NaN                                NaN
# 1                            21668.0                            22333.0
# 2                             3010.0                             3094.0
#
#    medicare_beneficiaries_total_2014  social_associations_2015  \
# 0                                NaN                    13.150
# 1                            23020.0                    11.636
# 2                             3132.0                     8.456
#
#    social_associations_2016  social_associations_2017  teen_births_2015  \
# 0                    13.757                    13.720              36.5
# 1                    12.018                    11.544              44.5
# 2                     8.125                     8.182              72.9
#
#    teen_births_2016  teen_births_2017  violent_crime_2015  violent_crime_2016  \
# 0              35.2              32.4              253.64              253.64
# 1              41.6              38.0              220.67              220.67
# 2              67.9              59.0              146.89              146.89
#
#    violent_crime_2017 geo_sumlevel_y      geo_id_y  food_insecurity_2015  \
# 0              265.70         county  05000US01001                 0.135
# 1              216.77         county  05000US01003                 0.135
# 2              328.66         county  05000US01005                 0.227
#
#    food_insecurity_2016  food_insecurity_2017  poor_mental_health_days_2015  \
# 0                 0.139                 0.144                           3.6
# 1                 0.137                 0.137                           3.8
# 2                 0.223                 0.233                           4.3
#
#    poor_mental_health_days_2016  poor_mental_health_days_2017 geo_sumlevel  \
# 0                           4.3                           4.2       county
# 1                           4.2                           4.0       county
# 2                           4.7                           4.8       county
#
#          geo_id  pop_2013  pop_2014  pop_2015  pop_2016
# 0  05000US01001   54907.0   55136.0   55221.0   55049.0
# 1  05000US01003  187114.0  191205.0  195121.0  199510.0
# 2  05000US01005   27321.0   27119.0   26932.0   26614.0

# %% [markdown]
# Weeding out the non-2016 data and other trash:

# %%
df = joiner[['geo_name', 'motor_vehicle_crash_deaths_2016',
             'income_2016', 'pop_2016',
             #'income_below_poverty_2016', 'pop_poverty_status_2016',
             'unemployment_2016', 'uninsured_2016', 'high_school_graduation_2016',
             'mean_commute_minutes_2016','alcoholimpaired_driving_deaths_2016', 
             'population_living_in_a_rural_area_2016', 'severe_housing_problems_2016',
             'adult_obesity_2016', 'social_associations_2016', 'teen_births_2016',
             'violent_crime_2016', 'food_insecurity_2016', 'poor_mental_health_days_2016'
            ]].copy()

# %% [markdown]
# Dropping null rows for some upcoming joins:

# %%
df = df.dropna()

# %% [markdown]
# #### First five rows of our raw data:

# %%
df.head()
# Out:
#              geo_name  motor_vehicle_crash_deaths_2016  income_2016  pop_2016  \
# 0  Autauga County, AL                            19.72      53099.0   55049.0
# 1  Baldwin County, AL                            15.90      51365.0  199510.0
# 2  Barbour County, AL                            18.22      33956.0   26614.0
# 3     Bibb County, AL                            23.92      39776.0   22572.0
# 4   Blount County, AL                            24.67      46212.0   57704.0
#
#    unemployment_2016  uninsured_2016  high_school_graduation_2016  \
# 0              0.059           0.134                        0.830
# 1              0.061           0.175                        0.800
# 2              0.108           0.174                        0.805
# 3              0.071           0.150                        0.810
# 4              0.061           0.176                        0.850
#
#    mean_commute_minutes_2016  alcoholimpaired_driving_deaths_2016  \
# 0                    25.5584                                0.318
# 1                    25.8497                                0.394
# 2                    23.4419                                0.391
# 3                    28.6987                                0.344
# 4                    34.3258                                0.192
#
#    population_living_in_a_rural_area_2016  severe_housing_problems_2016  \
# 0                                   0.420                         0.136
# 1                                   0.423                         0.147
# 2                                   0.678                         0.176
# 3                                   0.684                         0.130
# 4                                   0.900                         0.123
#
#    adult_obesity_2016  social_associations_2016  teen_births_2016  \
# 0               0.309                    13.757              35.2
# 1               0.267                    12.018              41.6
# 2               0.408                     8.125              67.9
# 3               0.401                     9.773              48.4
# 4               0.324                     8.467              45.3
#
#    violent_crime_2016  food_insecurity_2016  poor_mental_health_days_2016
# 0              253.64                 0.139                           4.3
# 1              220.67                 0.137                           4.2
# 2              146.89                 0.223                           4.7
# 3              235.95                 0.162                           4.6
# 4              219.03                 0.121                           4.5

# %% [markdown]
# Car crash deaths per 100k population is the value we're trying to predict.

# %% [markdown]
# Then we'll grab some political data:

# %%
url = 'https://raw.githubusercontent.com/tonmcg/US_County_Level_Election_Results_08-16/master/2016_US_County_Level_Presidential_Results.csv'
prez = pd.read_csv(url)

# %% [markdown]
# Some munging is required:

# %%
prez1 = prez.drop(['per_point_diff', 'diff'], axis=1)
prez1['trumpy'] = prez1['per_dem'] < prez1['per_gop']
prez1['trumpy'] = (prez1['trumpy'] == True).astype(int)

# %%
counties = []
for i in df.values:
        counties.append(i[0].split(',')[0]) # Getting rid of commas and states in county names
df['geo_name'] = np.array(counties)

# %% [markdown]
# Making sure our columns match before merges:

# %%
prez1.columns = ['Unnamed: 0', 'votes_dem', 'votes_gop', 'total_votes', 'per_dem',
       'per_gop', 'state_abbr', 'geo_name', 'combined_fips', 'trumpy']

prez = prez1[['geo_name','trumpy']].copy()

# %%
prez['geo_name'] = prez.geo_name.str.upper()
prez_final = prez[29:]

# %%
df['geo_name'] = df.geo_name.str.upper() # More merge prep - join will be on county names

# %% [markdown]
# Merging in political data to our initial county data:

# %%
df = pd.merge(df, prez_final.drop_duplicates(subset=['geo_name']), how='left', on='geo_name')

# %% [markdown]
# New first 5 rows:

# %%
df.head()
# Out:
#          geo_name  motor_vehicle_crash_deaths_2016  income_2016  pop_2016  \
# 0  AUTAUGA COUNTY                            19.72      53099.0   55049.0
# 1  BALDWIN COUNTY                            15.90      51365.0  199510.0
# 2  BARBOUR COUNTY                            18.22      33956.0   26614.0
# 3     BIBB COUNTY                            23.92      39776.0   22572.0
# 4   BLOUNT COUNTY                            24.67      46212.0   57704.0
#
#    unemployment_2016  uninsured_2016  high_school_graduation_2016  \
# 0              0.059           0.134                        0.830
# 1              0.061           0.175                        0.800
# 2              0.108           0.174                        0.805
# 3              0.071           0.150                        0.810
# 4              0.061           0.176                        0.850
#
#    mean_commute_minutes_2016  alcoholimpaired_driving_deaths_2016  \
# 0                    25.5584                                0.318
# 1                    25.8497                                0.394
# 2                    23.4419                                0.391
# 3                    28.6987                                0.344
# 4                    34.3258                                0.192
#
#    population_living_in_a_rural_area_2016  severe_housing_problems_2016  \
# 0                                   0.420                         0.136
# 1                                   0.423                         0.147
# 2                                   0.678                         0.176
# 3                                   0.684                         0.130
# 4                                   0.900                         0.123
#
#    adult_obesity_2016  social_associations_2016  teen_births_2016  \
# 0               0.309                    13.757              35.2
# 1               0.267                    12.018              41.6
# 2               0.408                     8.125              67.9
# 3               0.401                     9.773              48.4
# 4               0.324                     8.467              45.3
#
#    violent_crime_2016  food_insecurity_2016  poor_mental_health_days_2016  \
# 0              253.64                 0.139                           4.3
# 1              220.67                 0.137                           4.2
# 2              146.89                 0.223                           4.7
# 3              235.95                 0.162                           4.6
# 4              219.03                 0.121                           4.5
#
#    trumpy
# 0     1.0
# 1     1.0
# 2     1.0
# 3     1.0
# 4     1.0

# %% [markdown]
# Some final cleanup before we start exploring our data:

# %%
df = df.dropna() # We're row-rich enough to drop annoying null columns including Alaska
df['trumpy'] = df['trumpy'].astype('category')

# %% [markdown]
# Separating our target column from all the feature columns:

# %%
features = df.iloc[:,2:]
target = df.iloc[:,1]

# %% [markdown]
# Now we have our **features** columns and a **target** column.

# %% [markdown]
# ## Are our features normal?

# %%
for column in features:
    ax = sns.distplot(features[column])
    plt.show()
# Out:
# /anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# ### Are we feelin linear?

# %%
# sns.pairplot(df) # This takes forever to run never run ever ever

# %% [markdown]
# ### Is there multicolinearity?

# %%
corr = features.corr()
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
f, ax = plt.subplots(figsize=(11, 9))
cmap = sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# Now we will split our training and test sets.

# %%
X_train, X_test, y_train, y_test = train_test_split(features, target, random_state=39, test_size=0.2)

# %% [markdown]
# Just making some backups of our variables here for later down

# %%
X_train_orig = X_train 
X_test_orig = X_test
y_train_orig = y_train
y_test_orig = y_test

# %% [markdown]
# ## Scaling Data

# %% [markdown]
# Here we will put all our data in units of standard deviations from the mean.

# %%
scaler = preprocessing.StandardScaler()

# %%
scaler.fit(features.iloc[:,:-1])
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
features_scaled_train = pd.DataFrame(scaler.transform(X_train.iloc[:,:-1]), columns=X_train.columns[:-1], index=X_train.index)

features_scaled_train['trumpy']= X_train.trumpy
fst_train = features_scaled_train # making a backup for later

# %% [markdown]
# #### Here's our training data:

# %%
features_scaled_train.head()
# Out:
#       income_2016  pop_2016  unemployment_2016  uninsured_2016  \
# 1665     0.795095  0.397233          -1.339249       -0.112810
# 1054    -0.407368 -0.176693           0.458579       -0.673040
# 1244    -1.496332 -0.310794           0.409989        0.119010
# 1794    -0.670059  3.936245           0.750118       -0.093491
# 1077    -0.244947 -0.224163          -0.610400       -0.518494
#
#       high_school_graduation_2016  mean_commute_minutes_2016  \
# 1665                    -0.156857                  -0.122079
# 1054                     0.331784                   1.258898
# 1244                     0.665490                  -1.326618
# 1794                    -1.467847                   1.741761
# 1077                    -1.527437                  -0.931803
#
#       alcoholimpaired_driving_deaths_2016  \
# 1665                            -0.095877
# 1054                             0.667991
# 1244                            -0.876173
# 1794                            -0.506559
# 1077                            -0.054809
#
#       population_living_in_a_rural_area_2016  severe_housing_problems_2016  \
# 1665                               -1.184874                     -0.230521
# 1054                                1.160035                      0.409958
# 1244                               -0.637614                      0.409958
# 1794                               -1.770236                      2.212787
# 1077                                0.553891                      0.386236
#
#       adult_obesity_2016  social_associations_2016  teen_births_2016  \
# 1665           -0.243168                 -0.932136         -1.053452
# 1054            0.625032                  0.161314         -0.210115
# 1244            0.491463                  0.970869          2.506087
# 1794           -0.398999                 -0.983298          0.507269
# 1077           -0.510306                 -0.256805          0.490840
#
#       violent_crime_2016  food_insecurity_2016  poor_mental_health_days_2016  \
# 1665            0.390230             -0.047675                      0.589772
# 1054           -0.187228              0.137737                      0.245017
# 1244            1.315115              1.674010                      1.279281
# 1794            4.620953              1.568060                      1.796414
# 1077            0.085816             -0.418500                     -0.789248
#
#      trumpy
# 1665    1.0
# 1054    1.0
# 1244    1.0
# 1794    0.0
# 1077    1.0

# %% [markdown]
# #### And here's our testing data:

# %%
features_scaled_test = pd.DataFrame(scaler.transform(X_test.iloc[:,:-1]), columns=X_test.columns[:-1], index=X_test.index)

features_scaled_test['trumpy']= X_test.trumpy
fst_test = features_scaled_test # Backup

features_scaled_test.head()
# Out:
#       income_2016  pop_2016  unemployment_2016  uninsured_2016  \
# 1365     4.684509 -0.004193          -0.853349       -1.793501
# 1553    -0.631705 -0.125329           1.381787        0.601967
# 794      0.811846 -0.136017          -0.270270       -0.634404
# 1938     0.250300  0.171645           0.118449       -0.557130
# 378     -1.717694 -0.325534           2.645125        0.621285
#
#       high_school_graduation_2016  mean_commute_minutes_2016  \
# 1365                     1.285231                   1.526726
# 1553                    -0.514400                  -0.581444
# 794                      0.081504                   0.852989
# 1938                     1.154132                   0.201380
# 378                      0.975361                   0.549101
#
#       alcoholimpaired_driving_deaths_2016  \
# 1365                            -0.416209
# 1553                             0.528359
# 794                             -0.991164
# 1938                            -0.186227
# 378                             -1.024018
#
#       population_living_in_a_rural_area_2016  severe_housing_problems_2016  \
# 1365                               -0.052252                      0.386236
# 1553                               -0.429793                      1.169044
# 794                                -0.717278                     -0.942164
# 1938                               -1.087892                     -0.135635
# 378                                 0.363389                      1.809523
#
#       adult_obesity_2016  social_associations_2016  teen_births_2016  \
# 1365           -2.157660                 -0.491145         -2.093933
# 1553            1.582278                 -0.231927          0.709889
# 794             0.357893                 -1.131566         -0.571545
# 1938           -0.398999                 -1.037469          0.036314
# 378             1.114786                 -1.863275         -0.084162
#
#       violent_crime_2016  food_insecurity_2016  poor_mental_health_days_2016  \
# 1365           -1.109654             -2.140185                     -1.306380
# 1553            0.760846              1.753472                      0.589772
# 794            -0.770207             -0.789324                      0.072639
# 1938            1.406414              0.349637                      1.106904
# 378            -0.770106              3.263258                      1.279281
#
#      trumpy
# 1365    1.0
# 1553    1.0
# 794     1.0
# 1938    0.0
# 378     0.0

# %% [markdown]
# ## Baseline Prediction

# %% [markdown]
# The most basic form of predicting outcomes is just assuming it will be the average.

# %%
np.mean(y_train)
# Out:
# 18.53214905564063

# %%
# np.full((len(y_test), ), np.mean(y_train))

# %%
the_mean = np.full((len(y_test), ), np.mean(y_train))

print("MSE: ",metrics.mean_squared_error(y_test, the_mean))
print("RMSE: ",np.sqrt(metrics.mean_squared_error(y_test, the_mean)))
# Out:
# MSE:  69.91189669457229
# RMSE:  8.361333428022848

# %% [markdown]
# Here's what we get when we throw ALL of our variables at a model:

# %%
outcome = 'motor_vehicle_crash_deaths_2016'
predictors = df.iloc[:,2:]
predictors
pred_sum = "+".join(predictors.columns)
formula = outcome + "~" + pred_sum
model = ols(formula= formula, data=df).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                    OLS Regression Results
# ===========================================================================================
# Dep. Variable:     motor_vehicle_crash_deaths_2016   R-squared:                       0.600
# Model:                                         OLS   Adj. R-squared:                  0.597
# Method:                              Least Squares   F-statistic:                     227.5
# Date:                             Fri, 07 Dec 2018   Prob (F-statistic):               0.00
# Time:                                     11:57:41   Log-Likelihood:                -7547.1
# No. Observations:                             2449   AIC:                         1.513e+04
# Df Residuals:                                 2432   BIC:                         1.523e+04
# Df Model:                                       16
# Covariance Type:                         nonrobust
# ==========================================================================================================
#                                              coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------
# Intercept                                -10.4969      2.559     -4.102      0.000     -15.515      -5.479
# trumpy[T.1.0]                             -0.3946      0.303     -1.303      0.193      -0.989       0.199
# income_2016                             6.012e-05   1.76e-05      3.411      0.001    2.56e-05    9.47e-05
# pop_2016                               -5.549e-07   3.49e-07     -1.589      0.112   -1.24e-06     1.3e-07
# unemployment_2016                        -16.5423      7.829     -2.113      0.035     -31.895      -1.190
# uninsured_2016                            30.9611      3.216      9.628      0.000      24.655      37.267
# high_school_graduation_2016                1.9507      1.453      1.343      0.180      -0.899       4.800
# mean_commute_minutes_2016                 -0.0166      0.030     -0.560      0.575      -0.075       0.042
# alcoholimpaired_driving_deaths_2016        2.4324      0.889      2.736      0.006       0.689       4.176
# population_living_in_a_rural_area_2016    14.2704      0.588     24.288      0.000      13.118      15.423
# severe_housing_problems_2016             -18.7741      3.821     -4.913      0.000     -26.267     -11.281
# adult_obesity_2016                         8.8401      3.456      2.558      0.011       2.062      15.618
# social_associations_2016                   0.0640      0.027      2.365      0.018       0.011       0.117
# teen_births_2016                           0.1450      0.010     15.085      0.000       0.126       0.164
# violent_crime_2016                         0.0019      0.001      2.699      0.007       0.001       0.003
# food_insecurity_2016                      23.5415      4.852      4.852      0.000      14.027      33.056
# poor_mental_health_days_2016               0.5622      0.293      1.920      0.055      -0.012       1.136
# ==============================================================================
# Omnibus:                      878.381   Durbin-Watson:                   1.749
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             7346.553
# Skew:                           1.459   Prob(JB):                         0.00
# Kurtosis:                      10.967   Cond. No.                     2.91e+07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.91e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# We get an r^2 of .60, which is not the best.

# %%
print("MSE: ", model.mse_total)
print("RMSE: ", model.mse_total**.5)
# Out:
# MSE:  69.47824161759368
# RMSE:  8.335360917056542

# %% [markdown]
# ## Improved Regression

# %% [markdown]
# Maybe we can do better with some feature filtering methods?

# %% [markdown]
# From the p-values of the above test, we decide to drop some columns:

# %%
features_scaled_train = features_scaled_train.drop(['pop_2016',
                                                    'mean_commute_minutes_2016',
                                                   'high_school_graduation_2016',
                                                    'trumpy',
                                                    'poor_mental_health_days_2016'
                                                   ], axis=1)

features_scaled_test = features_scaled_test.drop(['pop_2016',
                                                  'mean_commute_minutes_2016',
                                                   'high_school_graduation_2016',
                                                    'trumpy',
                                                    'poor_mental_health_days_2016'], axis=1)

# %% [markdown]
# Let's engineer **a bunch of crazy polynomial and interaction terms:**

# %%
poly = preprocessing.PolynomialFeatures(degree=2, interaction_only=False, include_bias=False)
poly_features_train = pd.DataFrame(poly.fit_transform(features_scaled_train), columns=poly.get_feature_names(features_scaled_train.columns))
poly_features_test = pd.DataFrame(poly.fit_transform(features_scaled_test), columns=poly.get_feature_names(features_scaled_test.columns))

# %% [markdown]
# Let's drop any **columns with not enough variance to care about:**

# %%
def variance_threshold_selector(data, threshold=1.2):
    selector = VarianceThreshold(threshold)
    selector.fit(data)
    return data[data.columns[selector.get_support(indices=True)]]

features_selected_train = variance_threshold_selector(poly_features_train)

# %%
print(len(poly_features_train.columns))
len(features_selected_train.columns)
# Out:
# 77
# 35

# %% [markdown]
# Now we're gonna look at correlation coefficients between all our features:

# %%
# Create correlation matrix
corr_matrix = features_selected_train.corr().abs()

# Select upper triangle of correlation matrix
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))

# Find index of feature columns with correlation greater than 0.95
to_drop = [column for column in upper.columns if any(upper[column] > 0.75)]

# %% [markdown]
# Then we'll drop some more obviously colinear/redundant features:

# %%
features_selected_train.drop(columns=to_drop, inplace=True)
# Out:
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
len(features_selected_train.columns) # Down to just 32 columns
# Out:
# 32

# %% [markdown]
# We can run a script to pick the K most predictive features:

# %%
def information_selector(X, y, scoring, k):
    selector = SelectKBest(score_func=scoring, k=k)
    selector.fit(X, y)
    return X[X.columns[selector.get_support(indices=True)]]

# %%
features_selected_train = information_selector(features_selected_train, 
                                               y_train, mutual_info_regression, 
                                               k=15)

# %%
features_selected_test = poly_features_test[features_selected_train.columns]

# %%
corr = features_selected_train.corr()
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
f, ax = plt.subplots(figsize=(11, 9))
cmap = sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
lm = linear_model.LinearRegression()
lm.fit(features_selected_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
print('R^2: ', lm.score(features_selected_train, y_train))
# Out:
# R^2:  0.13982651170618254

# %%
filtered_y_preds = lm.predict(features_selected_test)

# %%
print("MSE: ",metrics.mean_squared_error(y_test, filtered_y_preds))
print("RMSE: ",np.sqrt(metrics.mean_squared_error(y_test, filtered_y_preds)))
# Out:
# MSE:  61.756596306296316
# RMSE:  7.858536524461556

# %% [markdown]
# Here's how we do:

# %%
plt.scatter(y_test, filtered_y_preds)

# %% [markdown]
# ## Lasso

# %%
from sklearn.linear_model import LassoCV

# %%
alphas = np.array(list(range(1,100)))/10000000
lassoReg = LassoCV(alphas=alphas, normalize=True)

lasso_xtrain = pd.DataFrame(poly.fit_transform(fst_train), columns=poly.get_feature_names(fst_train.columns))
lasso_xtest  = pd.DataFrame(poly.fit_transform(fst_test), columns=poly.get_feature_names(fst_test.columns))

lassoReg.fit(lasso_xtrain,y_train_orig)
y_pred = lassoReg.predict(lasso_xtest)
# Out:
# /anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /anaconda3/lib/python3.7/site-packages/sklearn/linear_model/coordinate_descent.py:492: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)

# %%
# poly = preprocessing.PolynomialFeatures(degree=2, interaction_only=False, include_bias=False)

# %%
coef = pd.DataFrame(data = lassoReg.coef_, index=lasso_xtrain.columns)
model_coef = coef.sort_values(by=0).T
model_coef.plot(kind='bar', title='Lasso Coefficients', legend=False, figsize=(16,10))

# %% [markdown]
# Our new Lasso r-squared:

# %%
print('R^2: ',lassoReg.score(lasso_xtest, y_test_orig))
# Out:
# R^2:  0.6524636212925269

# %%
lasso_y_preds = lassoReg.predict(lasso_xtest)

# %%
print("MSE: ",metrics.mean_squared_error(y_test, lasso_y_preds))
print("RMSE: ",np.sqrt(metrics.mean_squared_error(y_test, lasso_y_preds)))
# Out:
# MSE:  24.293394073979893
# RMSE:  4.928832932244701

# %% [markdown]
# Predicting the number of car crashes based on # of births per 1,000 female population, ages 15-19:

# %%
fig = plt.figure(figsize=(12,12))
sm.graphics.plot_regress_exog(model, "teen_births_2016", fig=fig)

# %%
ax1 = plt.scatter(lasso_xtest['teen_births_2016'], y_test, c='blue')
ax2 = plt.scatter(lasso_xtest['teen_births_2016'], lasso_y_preds, c='red')
