# %%
# re1.columns = re1.columns.str.lower()

# %%
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 100)

# %%
import pandas as pd

# %%
import numpy as np

# %%
from collections import Counter

# %%
# zxc = pd.read_json('https://data.ny.gov/resource/y8b4-725k.json')
# LOW TO MOD INCOME

# %%
# pd.read_json('https://data.ny.gov/resource/y8b4-725k.json')
# recyc = pd.read_json('https://data.cityofnewyork.us/resource/kuz6-hiwt.json')
# recyc.columns = listy
# recyc.columns
# Out:
# Index(['zone', 'mgp_cap_rate', 'paper_cap_rate', 'total_cap_rate', 'district',
#        'diversion_rate_total', 'fiscal_month_number', 'fiscal_year',
#        'month_name'],
#       dtype='object')

# %%
# re1 = pd.read_csv('/Users/sproul/Downloads/Solid_Waste_Management_Facilities.csv')
# len(re1.County.unique())
# re1.columns
# re1['activity desc'].unique()
# re1

# %%
# c=Counter(re1.City)
# c.most_common()
ffff = pd.read_csv('/Users/sproul/Downloads/Prod2016.csv')
rrrr
# Out:
#             County Well_Typ Wl_Status  MonthProd  GasProd  OilProd
# 0          Wyoming       GD        AC         12        1        0
# 1             Erie       GD        AC         12        1        0
# 2       Chautauqua       OD        AC         12        1        1
# 3      Cattaraugus       OD        AC         12        0       29
# 4       Chautauqua       GD        AC         12     3692        0
# 5       Chautauqua       GD        AC         12     3115        0
# 7       Chautauqua       GD        AC         12     2698        0
# 8         Allegany       OD        AC          2       35       10
# 11     Cattaraugus       OD        AC         12      343      103
# 12      Chautauqua       GD        AC         12     2495        0
# 13         Steuben       OD        AC         12       71       85
# 14        Allegany       OD        AC         12      158      153
# 15          Cayuga       GD        AC         12     1893        0
# ...

# %%
rrrr = rrrr.drop(['Field'], axis=1)
rrrr = rrrr[rrrr['MonthProd']!=0]

# %%
qqqq = rrrr['Completion']==0

# %%
len(qqqq[qqqq==False])
# Out:
# 364

# %%
# ({'AC': 10799,
#          'PB': 1,
#          'PA': 24,
#          'IN': 50,
#          'SI': 47,
#          'DD': 6,
#          'NR': 11,
#          'DG': 2,
#          'CO': 1})

# %%
# rrrr[rrrr['Wl_Status']=='PB']
# rrrr = rrrr[rrrr['Wl_Status']!='CO']
# rrrr = rrrr[rrrr['Wl_Status']!='NR']
# rrrr = rrrr[rrrr['Wl_Status']!='DG']

# %%
rrr = rrrr

# %%
rrrr['Well_Typ'].unique(), rrrr['Wl_Status'].unique()
# Out:
# (array(['GD', 'OD', 'GW', 'GE', 'OW', 'IW', 'NL', 'DW', 'OE'], dtype=object),
#  array(['AC', 'PA', 'IN', 'SI', 'DD', 'NR', 'DG', 'CO'], dtype=object))

# %%
rrrr = rrrr.drop(['WaterProd'], axis=1)

# %%
# # df = df[(df.GasProd > 3) | (df.WaterProd > 0) | (df.three > 0) & (df.four < 1)]
# to_drop = ['Clerk', 'Bagger']
# df[~df['title'].isin(to_drop)]
gapminder[~gapminder.continent.isin(continents) & 
           gapminder.year.isin(years)]
df[~df.countries.isin(countries)]
  countries
0        US
2   Germany

# %%
dddd = rrrr[~rrrr['OilProd'].isin(oils) | ~rrrr['GasProd'].isin(gases)]

# %%
# oils=[0]
# gases=[0,1,2,3]
dddd.groupby(['County']).all()
# Out:
#              Well_Typ  Wl_Status  GasProd  OilProd
# County
# Allegany         True       True    False    False
# Cattaraugus      True       True    False    False
# Cayuga           True       True     True    False
# Chautauqua       True       True    False    False
# Chemung          True       True     True    False
# Chenango         True       True     True    False
# Erie             True       True     True    False
# Genesee          True       True     True    False
# Livingston       True       True     True    False
# Madison          True       True     True    False
# Ontario          True       True     True    False
# Schuyler         True       True     True    False
# Seneca           True       True     True    False
# Steuben          True       True    False    False
# Wayne            True       True     True    False
# Wyoming          True       True     True    False
# Yates            True       True     True    False

# %%
# rrrr
dddd.columns
# Out:
# Index(['County', 'Well_Typ', 'Wl_Status', 'MonthProd', 'GasProd', 'OilProd'], dtype='object')

# %%
dddd = dddd.drop(['MonthProd'], axis=1)

# %%
len(dddd['County'].unique())
# Out:
# 17

# %%
# ffff

# %%
prac = pd.read_csv('/Users/sproul/Downloads/Prod2015.csv')

# %%
len(prac['County'].unique())
# Out:
# 25

# %%
#########

# %%
votes = pd.read_csv('/Users/sproul/Downloads/2016President-edit-for-ds1022.csv')
votes = votes.drop(['BLANK ON PURPOSE'], axis = 1)
votes['clinton_total'] = votes['Clinton   Kaine DEM']+votes['Clinton   Kaine WOR']+votes['Clinton   Kaine WEP']

# %%
votes.columns
# Out:
# Index(['County', 'Clinton   Kaine DEM', 'Trump    Pence REP',
#        'Trump    Pence CON', 'Clinton   Kaine WOR', 'Clinton   Kaine WEP'],
#       dtype='object')

# %%
votes['trump_total'] = votes['Trump    Pence REP']+votes['Trump    Pence CON']

# %%
# votes['trump_total']=0
# votes['clinton_total']=0
votes.head()
# Out:
#          County  Clinton   Kaine DEM  Trump    Pence REP  Trump    Pence CON  \
# 0        Albany                78504               42554                5254
# 1      Allegany                 4646               11421                1104
# 2        Broome                37106               37337                3606
# 3   Cattaraugus                 9077               17485                2207
# 4        Cayuga                12779               15316                2068
#
#    Clinton   Kaine WOR  Clinton   Kaine WEP  clinton_total  trump_total
# 0                 3419                 1148          83071        47808
# 1                  173                   63           4882        12525
# 2                 1631                  475          39212        40943
# 3                  274                  146           9497        19692
# 4                  541                  202          13522        17384

# %%
votes['Clinton   Kaine DEM']
# Out:
# dtype('int64')

# %%
# votes_edit = votes
votes_edit.columns
# Out:
# Index(['County', 'clinton_total', 'trump_total'], dtype='object')

# %%
df.columns = ['Name1', 'Name2', 'Name3'...]

# %%
# votes_edit = votes_edit.drop(['Clinton   Kaine DEM', 'Trump    Pence REP',
#        'Trump    Pence CON', 'Clinton   Kaine WOR', 'Clinton   Kaine WEP'], axis=1)
votes_edit.columns = ['county', 'clinton_total', 'trump_total']

# %%
votes_edit['county'] = votes_edit['county'].str.upper()

# %%
votes_edit = votes_edit.drop(['country'], axis=1)

# %%
votes_edit.head()
# Out:
#          county  clinton_total  trump_total
# 0        ALBANY          83071        47808
# 1      ALLEGANY           4882        12525
# 2        BROOME          39212        40943
# 3   CATTARAUGUS           9497        19692
# 4        CAYUGA          13522        17384

# %%
###################################################

# %%
# death = pd.read_json('https://health.data.ny.gov/resource/j36q-dvp6.json')

# %%
# df.loc[df['column_name'] == some_value]
# death1 = death[death['year']==2015]
# death1.year.unique()

# %%
###################################################

# %% [markdown]
# ## CRIME RATE

# %%
# c2016 = pd.read_csv('/Users/sproul/Downloads/2016-crime-nys.csv')
# c2016.head()
# c2017 = pd.read_csv('/Users/sproul/Downloads/2017-crime-nys.csv')
# c2017.head()
# c2017 = c2017.drop(['Unnamed: 8','Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11'], axis=1)
# c2016.columns = ['county' if t=='County_2016' else t for t in c2016.columns]
# c2016.columns
# c2017.columns = ['county' if t=='County_2017' else t for t in c2017.columns]
# c2017.columns
# crime1 = pd.merge(c2016, c2017, how='left', on='county')
# crime1['county'] = crime1['county'].str.upper()

# %%
####NOTES#### df.columns = ['log(gdp)' if x=='gdp' else x for x in df.columns] ########
# # votes_edit['county'] = votes_edit['county'].str.upper()

# %%
crime1.head()
# Out:
#         county 2016 Population Index_C_Count_2016 Index_C_Rate_2016  \
# 0       Albany         308,401              8,767           2,842.7
# 1     Allegany          46,858                571           1,218.6
# 2        Bronx       1,458,255             36,834           2,525.9
# 3       Broome         194,518              5,422           2,787.4
# 4  Cattaraugus          75,126              1,232           1,639.9
#
#   Violent_C_Count_2016  Violent_C_Rate_2016 Property_C_Count_2016  \
# 0                1,099                356.4                 7,668
# 1                   81                172.9                   490
# 2               13,817                947.5                23,017
# 3                  641                329.5                 4,781
# 4                  138                183.7                 1,094
#
#   Property_C_Rate_2016 2017 Population Index_C_Count_2017 Index_C_Rate_2017  \
# 0              2,486.4         310,352              8,777           2,828.1
# ...

# %%
crime1.columns
# Out:
# Index(['county', '2016 Population', 'Index_C_Count_2016', 'Index_C_Rate_2016',
#        'Violent_C_Count_2016', 'Violent_C_Rate_2016', 'Property_C_Count_2016',
#        'Property_C_Rate_2016', '2017 Population', 'Index_C_Count_2017',
#        'Index_C_Rate_2017', 'Violent_C_Count_2017', 'Violent_C_Rate_2017',
#        'Property_C_Count_2017', 'Property_C_Rate_2017'],
#       dtype='object')

# %%
crime_pop = crime1[['2016 Population','2017 Population']]

# %%
for c in crime_pop:
    print(c)
    
# crime_pop
# Out:
# 2016 Population
# 2017 Population

# %%
# crime1['pop_mean'] = (crime1['2016 Population'] + crime1['2017 Population'])/2

# %%
# crime1['2017 Population'].astype(int)

# %%
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
import seaborn as sns

# %%
prez = pd.read_csv('https://raw.githubusercontent.com/tonmcg/US_County_Level_Election_Results_08-16/master/2016_US_County_Level_Presidential_Results.csv')

# %%
prez1 = prez.drop(['per_point_diff', 'diff'], axis=1)
# prez1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-46728ebd504a> in <module>
# ----> 1 prez1 = prez.drop(['per_point_diff', 'diff'], axis=1)
#       2 # prez1
#
# NameError: name 'prez' is not defined

# %%
prez1['trumpy'] = prez1['per_dem'] < prez1['per_gop']

# %%
prez1['trumpy'] = (prez1['trumpy'] == True).astype(int)

# %%
df['COL2'] = (df['COL2'] == 'TRUE').astype(int)

# %%
for i in prez1['trumpy']:
    print(type(i))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# ...

# %%
prez1
# Out:
#       votes_dem  votes_gop  total_votes   per_dem   per_gop state_abbr  \
# 0       93003.0   130413.0     246588.0  0.377159  0.528870         AK
# 1       93003.0   130413.0     246588.0  0.377159  0.528870         AK
# 2       93003.0   130413.0     246588.0  0.377159  0.528870         AK
# 3       93003.0   130413.0     246588.0  0.377159  0.528870         AK
# 4       93003.0   130413.0     246588.0  0.377159  0.528870         AK
# 5       93003.0   130413.0     246588.0  0.377159  0.528870         AK
# 6       93003.0   130413.0     246588.0  0.377159  0.528870         AK
# 7       93003.0   130413.0     246588.0  0.377159  0.528870         AK
# 8       93003.0   130413.0     246588.0  0.377159  0.528870         AK
# 9       93003.0   130413.0     246588.0  0.377159  0.528870         AK
# 10      93003.0   130413.0     246588.0  0.377159  0.528870         AK
# 11      93003.0   130413.0     246588.0  0.377159  0.528870         AK
# ...

# %%
# prez2 = prez1
